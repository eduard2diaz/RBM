# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.decomposition import PCA

# %%
img = mpimg.imread('./original.png')
print(img.shape)
plt.imshow(img)
# Out:
# (213, 212, 3)

# %%
# Out:
# (960, 957, 3)

# %%
img_first_channel = img[:,:,0]

# %%
plt.imshow(img_first_channel)

# %%
plt.imshow(img_first_channel, cmap='gray')

# %%
import numpy as np

def reduction(img, n_components = -1):
    if n_components == -1:
        pca = PCA()
    else:
        pca = PCA(n_components)
        
    reduced = pca.fit_transform(img)
    reduced_recovered = pca.inverse_transform(reduced)
    
    percentage = np.cumsum(pca.explained_variance_ratio_ * 100)[-1]
    
    fig, ax = plt.subplots()
    ax.imshow(reduced_recovered, cmap='gray')
    plt.show()
    return percentage

# %%
percentage = 0
n_components = 1
variance_percentage_limit = 99
while percentage < variance_percentage_limit:
    percentage = reduction(img_first_channel, n_components)
    print(f'N_components: {n_components} Variance porcentaje {percentage}%')
    n_components+= 1
# Out:
# N_components: 1 Variance porcentaje 58.95730202605289%
# N_components: 2 Variance porcentaje 73.5613099559532%
# N_components: 3 Variance porcentaje 79.96297611480301%
# N_components: 4 Variance porcentaje 84.41107293494981%
# N_components: 5 Variance porcentaje 87.61268693602375%
# N_components: 6 Variance porcentaje 89.88299530467388%
# N_components: 7 Variance porcentaje 91.40709056633803%
# N_components: 8 Variance porcentaje 92.72341489242957%
# N_components: 9 Variance porcentaje 93.6335740540983%
# N_components: 10 Variance porcentaje 94.38956286111336%
# N_components: 11 Variance porcentaje 94.9321494943811%
# N_components: 12 Variance porcentaje 95.357052176094%
# N_components: 13 Variance porcentaje 95.67570895108203%
# N_components: 14 Variance porcentaje 95.96653326057306%
# N_components: 15 Variance porcentaje 96.20158984821876%
# N_components: 16 Variance porcentaje 96.40777513976929%
# N_components: 17 Variance porcentaje 96.59841094258692%
# N_components: 18 Variance porcentaje 96.77128858641878%
# N_components: 19 Variance porcentaje 96.92479324286018%
# N_components: 20 Variance porcentaje 97.05786472861209%
# N_components: 21 Variance porcentaje 97.17796585474443%
# N_components: 22 Variance porcentaje 97.29337788842437%
# N_components: 23 Variance porcentaje 97.40391646913382%
# N_components: 24 Variance porcentaje 97.50069711348681%
# N_components: 25 Variance porcentaje 97.59087954150787%
# N_components: 26 Variance porcentaje 97.67463531454041%
# N_components: 27 Variance porcentaje 97.75599358397119%
# N_components: 28 Variance porcentaje 97.8277003188955%
# N_components: 29 Variance porcentaje 97.89560015698103%
# N_components: 30 Variance porcentaje 97.95485480212147%
# N_components: 31 Variance porcentaje 98.00985309322142%
# N_components: 32 Variance porcentaje 98.06202622017334%
# N_components: 33 Variance porcentaje 98.1116757860634%
# N_components: 34 Variance porcentaje 98.15534220618126%
# N_components: 35 Variance porcentaje 98.19692350669575%
# N_components: 36 Variance porcentaje 98.23743926156075%
# N_components: 37 Variance porcentaje 98.27694164554052%
# N_components: 38 Variance porcentaje 98.3136936968833%
# N_components: 39 Variance porcentaje 98.34927013461618%
# N_components: 40 Variance porcentaje 98.38323365784086%
# N_components: 41 Variance porcentaje 98.4149559610682%
# N_components: 42 Variance porcentaje 98.44596244777094%
# N_components: 43 Variance porcentaje 98.47614377719852%
# N_components: 44 Variance porcentaje 98.50531580902128%
# N_components: 45 Variance porcentaje 98.53324854922086%
# N_components: 46 Variance porcentaje 98.56100645137496%
# N_components: 47 Variance porcentaje 98.58684693721678%
# N_components: 48 Variance porcentaje 98.61239486515578%
# N_components: 49 Variance porcentaje 98.63675604940158%
# N_components: 50 Variance porcentaje 98.66023570612195%
# N_components: 51 Variance porcentaje 98.68336719372124%
# N_components: 52 Variance porcentaje 98.70636969955171%
# N_components: 53 Variance porcentaje 98.72865146200526%
# N_components: 54 Variance porcentaje 98.74957043524736%
# N_components: 55 Variance porcentaje 98.77010309330228%
# N_components: 56 Variance porcentaje 98.79019009660983%
# N_components: 57 Variance porcentaje 98.8092994470904%
# N_components: 58 Variance porcentaje 98.82879094524358%
# N_components: 59 Variance porcentaje 98.84768373704705%
# N_components: 60 Variance porcentaje 98.86599605120219%
# N_components: 61 Variance porcentaje 98.88345094058418%
# N_components: 62 Variance porcentaje 98.90042550888579%
# N_components: 63 Variance porcentaje 98.91763996179256%
# N_components: 64 Variance porcentaje 98.93451483572636%
# N_components: 65 Variance porcentaje 98.9509424016004%
# N_components: 66 Variance porcentaje 98.96695915044872%
# N_components: 67 Variance porcentaje 98.98264220899785%
# N_components: 68 Variance porcentaje 98.99810597644745%
# N_components: 69 Variance porcentaje 99.01357008550904%
